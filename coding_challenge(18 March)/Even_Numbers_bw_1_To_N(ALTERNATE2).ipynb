# %% [markdown]
# <a href="https://colab.research.google.com/github/RonitARK/Davis_Training/blob/main/coding_challenge(18%20March)/Even_Numbers_bw_1_To_N(ALTERNATE2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 14: Print all even numbers between 1 to N.
#
# Input: Enter N
#
# Output: Even numbers list

# %%
n = int(input("Enter N: "))
evens_list = list(range(2, n + 1, 2))
print("Even numbers list:", evens_list)
